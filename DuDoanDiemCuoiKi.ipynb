# 36  40              7  ...  2020-11-02 04:26:35  2020-11-03 14:46:58
# 37  41              7  ...  2020-11-02 04:27:13  2020-11-03 13:54:00
# 38  42              7  ...  2020-11-02 04:28:03  2020-11-03 13:54:00
# 39  43              7  ...  2020-11-02 04:28:16  2020-11-03 13:54:00
# 40  44              7  ...  2020-11-02 04:30:20  2020-11-03 13:54:00
# 41  45              7  ...  2020-11-02 04:31:45  2020-11-03 13:54:00
# 42  46              7  ...  2020-11-02 04:31:53  2020-11-03 13:54:00
# 43  47              7  ...  2020-11-02 04:31:54  2020-11-04 04:02:29
# 44  48              7  ...  2020-11-02 04:32:01  2020-11-03 13:54:00
# 45  49              7  ...  2020-11-02 04:32:03  2020-11-03 13:54:00
# 46  50              7  ...  2020-11-02 04:32:18  2020-11-03 13:54:00
# 47  51              7  ...  2020-11-02 04:32:18  2020-11-03 13:54:00
# 48  52              7  ...  2020-11-02 04:32:25  2020-11-03 13:54:00
# 49  53              7  ...  2020-11-02 04:32:38  2020-11-03 13:54:00
#
# [50 rows x 12 columns]

# %%
url2='https://raw.githubusercontent.com/nguyenhuong2001/DuDoanDiemThiCuoiKi/main/score_training.csv'
score=pd.read_csv(url2)
score
# Out:
#        id   QT   GK   TH   CK  TBM  TBTL
# 0      22   10    9  8.5  8.5  8.8  8.52
# 1      24   10    8   10  9.5  9.4  8.41
# 2      27   10   10   10   10   10  8.67
# 3      28   10  9.5  7.5  9.5  9.2  7.39
# 4      29   10  9.5    5  8.5  8.2  8.05
# ..    ...  ...  ...  ...  ...  ...   ...
# 970  1857    5  4.5   10    4    6  6.03
# 971  1859    8    5   10  1.5  5.4  5.06
# 972  1862    5  6.5    1  7.5  5.1  4.71
# 973  1865  6.5         3  7.5       6.89
# 974  1866    9  7.5    2    5    5  7.05
#
# [975 rows x 7 columns]

# %% [markdown]
# **Bỏ một số cột không cần thiết**

# %%
wecode_new=wecode[['id','user_id','assignment_id','problem_id','is_final','status','pre_score','coefficient']]
wecode_new.head()
# Out:
#    id  user_id  assignment_id  ...             status  pre_score coefficient
# 0   4        4              0  ...              SCORE      10000         100
# 1   5        4              0  ...              SCORE      10000         100
# 2   6        4              0  ...  Compilation Error          0         100
# 3   7        4              0  ...  Compilation Error          0         100
# 4   8        4              0  ...  Compilation Error          0         100
#
# [5 rows x 8 columns]

# %%
score_new= score[['id','CK']]
score_new=score_new.rename (columns={'id':'user_id'}) 
score_new
# Out:
#      user_id   CK
# 0         22  8.5
# 1         24  9.5
# 2         27   10
# 3         28  9.5
# 4         29  8.5
# ..       ...  ...
# 970     1857    4
# 971     1859  1.5
# 972     1862  7.5
# 973     1865  7.5
# 974     1866    5
#
# [975 rows x 2 columns]

# %% [markdown]
# **Gom nhóm dữ liệu**

# %%
#Tổng các problem có submit
wecode1= wecode_new.groupby ('user_id',as_index=False).problem_id.nunique()
wecode1=wecode1.rename(columns={'problem_id':'sum_problem'})
wecode1
# Out:
#       user_id  sum_problem
# 0           1            2
# 1           4           41
# 2           5            5
# 3           6           88
# 4           7            2
# ...       ...          ...
# 1154     1860           43
# 1155     1862            6
# 1156     1864           63
# 1157     1865           17
# 1158     1868           20
#
# [1159 rows x 2 columns]

# %%
#Tổng số lần submit
wecode2= wecode_new.groupby('user_id',as_index= False).id.count()
wecode2=wecode2.rename (columns={'id':'count_submit'}) 
wecode2
# Out:
#       user_id  count_submit
# 0           1             2
# 1           4            54
# 2           5             6
# 3           6           130
# 4           7             5
# ...       ...           ...
# 1154     1860            76
# 1155     1862            12
# 1156     1864           187
# 1157     1865            99
# 1158     1868            47
#
# [1159 rows x 2 columns]

# %% [markdown]
# Đoạn groupby này có tham khảo nhóm của bạn Cao Hưng Phú

# %%
# Tổng số điểm của những bài có (is_final=1)
df=wecode_new.groupby('user_id')
wecode3=pd.DataFrame ({'sum_score':df.apply(lambda x:x[ x['is_final']==1]['pre_score'].sum())})# đoạn này tham khảo nè
wecode3
# Out:
#          sum_score
# user_id
# 1            10000
# 4           370000
# 5            30000
# 6           850000
# 7             9209
# ...            ...
# 1860        329665
# 1862         40000
# 1864        439741
# 1865        116428
# 1868        270000
#
# [1159 rows x 1 columns]

# %%
#Tổng số lần submit đúng (pre_score=10000)
wecode4 =pd.DataFrame({'pre_full':df['pre_score'].apply(lambda x:( x==10000).sum())   })
wecode4
# Out:
#          pre_full
# user_id
# 1               1
# 4              44
# 5               3
# 6              89
# 7               0
# ...           ...
# 1860           29
# 1862            4
# 1864           30
# 1865           10
# 1868           38
#
# [1159 rows x 1 columns]

# %% [markdown]
# Gộp các bảng lại thành 1 bảng

# %%
data_index1=pd.merge(wecode1,wecode2,how='left',on='user_id')
data_index2=pd.merge(data_index1,wecode3,how='left',on='user_id')
data_index3=pd.merge (data_index2,wecode4, how='left',on='user_id')
data = pd.merge(data_index3,score_new,how='left',on='user_id')
data.head(20)
# Out:
#     user_id  sum_problem  count_submit  sum_score  pre_full   CK
# 0         1            2             2      10000         1  NaN
# 1         4           41            54     370000        44  NaN
# 2         5            5             6      30000         3  NaN
# 3         6           88           130     850000        89  NaN
# 4         7            2             5       9209         0  NaN
# 5        11           18            50     100316        19  NaN
# 6        14            7            22      68000         7  NaN
# 7        15           50           101     458666        56  NaN
# 8        20           12            13     120000        12  NaN
# 9        24           78           164     750299        80  9.5
# 10       27            5            13      39000         4   10
# 11       29           80           199     762760        75  8.5
# 12       31            3            13      30000         3  NaN
# 13       34           84           218     822888        81  6.5
# 14       35          147           297    1477000       152  4.5
# 15       37          102           312     979712       100  7.5
# 16       40          191           664    2111388       227    8
# 17       41           71           110     636888        64    8
# 18       42          181           324    1925142       192  7.5
# 19       43           98           448    1541357       175    6

# %% [markdown]
# **Tách ra 2 bảng : bảng có điểm cuối kỳ và bảng chưa có điểm cuối kỳ**

# %%
data_predict=data[pd.isnull(data["CK"])]
data_predict.head(20)
# Out:
#     user_id  sum_problem  count_submit  sum_score  pre_full   CK
# 0         1            2             2      10000         1  NaN
# 1         4           41            54     370000        44  NaN
# 2         5            5             6      30000         3  NaN
# 3         6           88           130     850000        89  NaN
# 4         7            2             5       9209         0  NaN
# 5        11           18            50     100316        19  NaN
# 6        14            7            22      68000         7  NaN
# 7        15           50           101     458666        56  NaN
# 8        20           12            13     120000        12  NaN
# 12       31            3            13      30000         3  NaN
# 24       51           39            86     380000        40  NaN
# 31       65           60           186     622000        72  NaN
# 40       83          104           490    1035978       110  NaN
# 42       87          105           391    1154120       124  NaN
# 45       90          207           530    2275904       229  NaN
# 46       91           95           153     896363        89  NaN
# 56      105           66           184     516370        45  NaN
# 62      124           94           263     920745        92  NaN
# 65      131           88           171     878888        87  NaN
# 81      165          161           547    1643448       172  NaN

# %%
data_training= data[pd.notnull(data["CK"])]
data_training.head(20)
# Out:
#     user_id  sum_problem  count_submit  sum_score  pre_full   CK
# 9        24           78           164     750299        80  9.5
# 10       27            5            13      39000         4   10
# 11       29           80           199     762760        75  8.5
# 13       34           84           218     822888        81  6.5
# 14       35          147           297    1477000       152  4.5
# 15       37          102           312     979712       100  7.5
# 16       40          191           664    2111388       227    8
# 17       41           71           110     636888        64    8
# 18       42          181           324    1925142       192  7.5
# 19       43           98           448    1541357       175    6
# 20       45           66           161     601388        56  7.5
# 21       47           67           186     666000        70    4
# 22       48           25            26     225285        19    3
# 23       49           99           313     984602       101  5.5
# 25       52          100           349     973888        97  4.5
# 26       53          129           400    1159627       108    6
# 27       55           86           208     827888        84  4.5
# 28       57           87           323    1399776       147    8
# 29       59            8            26      70000         7  6.5
# 30       64           25            55     229285        21    9

# %%
exits = 0 in data_training['sum_problem']
exits
# Out:
# False

# %%
exits1 = 0 in data_training['count_submit']
exits1
# Out:
# False

# %% [markdown]
# Biểu diễn dưới dạng biểu đồ

# %% [markdown]
# - sum_problem : tổng số problem đã submit
# - count_submit : tổng số lần submit
# - sum_score : Tổng số điểm của những bài có (is_final=1)
# - pre_full : số lần submit đúng (pre_score=10000)
# **************************************
# CÁC CÔNG THỨC CÓ THỂ TÍNH :
# 1. Tổng số điểm của những bài có (is_final=1)
# 2. Số lần submit đúng
# 3. Tổng số lần submit
# 4. Tổng số problem đã submit  => BO
# 5. Số lần submit đúng /  Tổng số problem đã submit (Heso_submit1)
# 6. Số lần submit đúng /  Tổng số lần submit(Heso_submit2)
# 7. Tổng số prolem đã submit / Tổng số lần submit  (Heso_submit3)

# %% [markdown]
# # **Vẽ biểu đồ**

# %%
#1. TỔNG SỐ ĐIỂM CỦA NHỮNG BÀI CÓ (is_final=1)
data_training=data_training.sort_values (by='CK')# sắp xếp điểm cuối kì theo thứ tự tăng dần
plt.scatter (x=data_training['sum_score'], y= data_training['CK'])
plt.xlabel("Total score")
plt.ylabel("Final score")
plt.title ("First Plot")
plt.show()

# %% [markdown]
# Nhận xét :
#
# * Tổng điểm của mỗi user_id có xu hướng phân bổ không đều và tăng dần theo số điểm cuối kì.

# %%
#2. Số lần submit đúng 
data_training=data_training.sort_values (by='CK')
plt.scatter (x=data_training['pre_full'], y= data_training['CK'])
plt.xlabel("Number of correct submissions")
plt.ylabel("Final score")
plt.title ("Second Plot")
plt.show()

# %%
#3. Tổng số lần submit
data_training=data_training.sort_values (by='CK')
plt.scatter (x=data_training['count_submit'], y= data_training['CK'])
plt.xlabel("Total number of submissions")
plt.ylabel("Final score")
plt.title ("Third Plot")
plt.show()

# %%
data_training= data[pd.notnull(data["CK"])]

# %% [markdown]
# Nhận xét :
#
# *Tổng số lần submit của các user phân bổ không đều, có xu hướng tăng dần theo điểm cuối kì
# * Những user có số lần nộp cao hơn 500 đa số có số điểm từ 5 điểm trở lên, còn những user có số lần submit dưới 500, đa số có điểm cuối kỳ dưới 5 điểm.
# * Có vẻ là những user nào có số lần submit nhiều thì điểm cuối kì đa số đạt điểm số cao.

# %%
# Thêm 3 cột : 
#Số lần submit đúng / Tổng số problem đã submit  (Heso_submit1)
#Số lần submit đúng / Tổng số lần submit         (Heso_submit2)
#Tổng số prolem đã submit / Tổng số lần submit   (Heso_submit3)
data_training['Heso_submit1'] =data_training.apply(lambda x: x['pre_full'] / x['sum_problem'], axis=1)

data_training.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
#     user_id  sum_problem  count_submit  sum_score  pre_full   CK  Heso_submit1
# 9        24           78           164     750299        80  9.5      1.025641
# 10       27            5            13      39000         4   10      0.800000
# 11       29           80           199     762760        75  8.5      0.937500
# 13       34           84           218     822888        81  6.5      0.964286
# 14       35          147           297    1477000       152  4.5      1.034014
# 15       37          102           312     979712       100  7.5      0.980392
# 16       40          191           664    2111388       227    8      1.188482
# 17       41           71           110     636888        64    8      0.901408
# 18       42          181           324    1925142       192  7.5      1.060773
# 19       43           98           448    1541357       175    6      1.785714

# %%
#4. Số lần đạt điểm tối đa trên tổng số problem
data_training=data_training.sort_values(by='CK')
plt.scatter (data_training['Heso_submit1'], y= data_training['CK'])
plt.title ("Fourth Plot")
plt.xlabel("Heso_submit1")
plt.ylabel("Final score")
plt.show()

# %%
data_training= data[pd.notnull(data["CK"])]

# %%
data_training['Heso_submit2'] =data_training.apply(lambda x: x['pre_full'] / x['count_submit'], axis=1)
data_training.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     user_id  sum_problem  count_submit  sum_score  pre_full   CK  Heso_submit2
# 9        24           78           164     750299        80  9.5      0.487805
# 10       27            5            13      39000         4   10      0.307692
# 11       29           80           199     762760        75  8.5      0.376884
# 13       34           84           218     822888        81  6.5      0.371560
# 14       35          147           297    1477000       152  4.5      0.511785
# 15       37          102           312     979712       100  7.5      0.320513
# 16       40          191           664    2111388       227    8      0.341867
# 17       41           71           110     636888        64    8      0.581818
# 18       42          181           324    1925142       192  7.5      0.592593
# 19       43           98           448    1541357       175    6      0.390625

# %%
#5. Tổng số lần submit đúng / tổng submit
data_training=data_training.sort_values(by='CK')
plt.scatter (data_training['Heso_submit2'], y= data_training['CK'])
plt.title ("Fifth Plot")
plt.xlabel("Heso_submit2")
plt.ylabel("Final score")
plt.show()

# %%
data_training= data[pd.notnull(data["CK"])]

# %%
data_training['Heso_submit3'] =data_training.apply(lambda x: x['sum_problem'] / x['count_submit'], axis=1)
data_training.head(10)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#     user_id  sum_problem  count_submit  sum_score  pre_full   CK  Heso_submit3
# 9        24           78           164     750299        80  9.5      0.475610
# 10       27            5            13      39000         4   10      0.384615
# 11       29           80           199     762760        75  8.5      0.402010
# 13       34           84           218     822888        81  6.5      0.385321
# 14       35          147           297    1477000       152  4.5      0.494949
# 15       37          102           312     979712       100  7.5      0.326923
# 16       40          191           664    2111388       227    8      0.287651
# 17       41           71           110     636888        64    8      0.645455
# 18       42          181           324    1925142       192  7.5      0.558642
# 19       43           98           448    1541357       175    6      0.218750

# %%
#6. Tổng problem đã submit / Tổng submit
data_training=data_training.sort_values(by='CK')
plt.scatter (data_training['Heso_submit3'], y= data_training['CK'])
plt.title ("Sixth Plot")
plt.xlabel("Heso_submit3")
plt.ylabel("Final score")
plt.show()
